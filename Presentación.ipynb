# %% [markdown]
# <a href="https://colab.research.google.com/github/Almale44/Diplomado-/blob/main/Presentaci%C3%B3n.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import plotly as plo
import plotly.express as px #Rename as px

# %%
df=pd.read_excel('/content/drive/MyDrive/Diplomado/Popular_Spotify_Songs.xlsx', sheet_name='Popular_Spotify_Songs')
df
# Out:
#                               track_name      artist(s)_name  artist_count  \
# 0    Seven (feat. Latto) (Explicit Ver.)    Latto, Jung Kook             2
# 1                                   LALA         Myke Towers             1
# 2                                vampire      Olivia Rodrigo             1
# 3                           Cruel Summer        Taylor Swift             1
# 4                         WHERE SHE GOES           Bad Bunny             1
# ..                                   ...                 ...           ...
# 948                         My Mind & Me        Selena Gomez             1
# 949            Bigger Than The Whole Sky        Taylor Swift             1
# 950                 A Veces (feat. Feid)  Feid, Paulo Londra             2
# 951                        En La De Ella  Feid, Sech, Jhayco             3
# 952                                Alone           Burna Boy             1
#
# ...

# %%
# @title released_day

from matplotlib import pyplot as plt
df['released_day'].plot(kind='hist', bins=20, title='released_day')
plt.gca().spines[['top', 'right',]].set_visible(False)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 953 entries, 0 to 952
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   track_name            953 non-null    object
#  1   artist(s)_name        953 non-null    object
#  2   artist_count          953 non-null    int64
#  3   released_year         953 non-null    int64
#  4   released_month        953 non-null    int64
#  5   released_day          953 non-null    int64
#  6   in_spotify_playlists  953 non-null    int64
#  7   in_spotify_charts     953 non-null    int64
#  8   streams               953 non-null    object
#  9   in_apple_playlists    953 non-null    int64
#  10  in_apple_charts       953 non-null    int64
# dtypes: int64(8), object(3)
# memory usage: 82.0+ KB

# %%
df.describe()
# Out:
#        artist_count  released_year  released_month  released_day  \
# count    953.000000     953.000000      953.000000    953.000000
# mean       1.556139    2018.238195        6.033578     13.930745
# std        0.893044      11.116218        3.566435      9.201949
# min        1.000000    1930.000000        1.000000      1.000000
# 25%        1.000000    2020.000000        3.000000      6.000000
# 50%        1.000000    2022.000000        6.000000     13.000000
# 75%        2.000000    2022.000000        9.000000     22.000000
# max        8.000000    2023.000000       12.000000     31.000000
#
#        in_spotify_playlists  in_spotify_charts  in_apple_playlists  \
# count            953.000000         953.000000          953.000000
# mean            5200.124869          12.009444           67.812172
# std             7897.608990          19.575992           86.441493
# min               31.000000           0.000000            0.000000
# ...

# %% [markdown]
# 1. ¿Existen canciones que tengan la misma cantida de reproducciones?

# %%
df['streams'].value_counts()
# Out:
# 723894473     2
# 156338624     2
# 1223481149    2
# 395591396     2
# 1695712020    1
#              ..
# 1357608774    1
# 294352144     1
# 972164968     1
# 920045682     1
# 96007391      1
# Name: streams, Length: 949, dtype: int64

# %% [markdown]
# ¿Qué artistas aparecen?

# %%
df['artist(s)_name'].unique()
# Out:
# array(['Latto, Jung Kook', 'Myke Towers', 'Olivia Rodrigo',
#        'Taylor Swift', 'Bad Bunny', 'Dave, Central Cee',
#        'Eslabon Armado, Peso Pluma', 'Quevedo', 'Gunna',
#        'Peso Pluma, Yng Lvcas', 'Bad Bunny, Grupo Frontera', 'NewJeans',
#        'Miley Cyrus', 'David Kushner', 'Harry Styles', 'SZA',
#        'Fifty Fifty', 'Billie Eilish', 'Feid, Young Miko', 'Jimin',
#        'Gabito Ballesteros, Junior H, Peso Pluma', 'Arctic Monkeys',
#        'Bizarrap, Peso Pluma', 'The Weeknd, Madonna, Playboi Carti',
#        'Fuerza Regida', 'Rï¿½ï¿½ma, Selena G', 'Tainy, Bad Bunny',
#        'Morgan Wallen', 'Dua Lipa', 'Troye Sivan',
#        'Peso Pluma, Grupo Frontera',
#        'The Weeknd, 21 Savage, Metro Boomin', 'Karol G, Shakira',
#        'Big One, Duki, Lit Killah, Maria Becerra, FMK, Rusherking, Emilia, Tiago pzk',
#        'Yahritza Y Su Esencia, Grupo Frontera', 'Junior H, Peso Pluma',
#        'Post Malone, Swae Lee', 'Bebe Rexha, David Guetta',
# ...

# %% [markdown]
# ¿Cuantos artistas aparecen?

# %%
df['artist(s)_name'].nunique()
# Out:
# 645

# %% [markdown]
# Artistas con más canciones

# %%
df['artist(s)_name'].value_counts()
# Out:
# Taylor Swift                 34
# The Weeknd                   22
# Bad Bunny                    19
# SZA                          19
# Harry Styles                 17
#                              ..
# Karol G, Ovy On The Drums     1
# Coolio, L.V.                  1
# Kordhell                      1
# Kenia OS                      1
# Feid, Sech, Jhayco            1
# Name: artist(s)_name, Length: 645, dtype: int64

# %%
dff=df['artist(s)_name'].value_counts().index()

# %%
def format_title(title, subtitle=None, subtitle_font_size=14):
        title = f'<b>{title}</b>'
        if not subtitle:
            return title
        subtitle = f'<span style="font-size: {subtitle_font_size}px;">{subtitle}</span>'
        return f'{title}<br>{subtitle}'
fig=px.bar(df,x='track_name', y='streams')
fig.update_layout(
    yaxis_title='Reproducciones',
    xaxis_title='Canción',
    title_text= format_title('Spotify Songs','Proyecto'),
    template='plotly_white')
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_tay=df[(df['artist(s)_name']=='Taylor Swift')]
df_tay
# Out:
#                                             track_name artist(s)_name  \
# 3                                         Cruel Summer   Taylor Swift
# 21   I Can See You (Taylorï¿½ï¿½ï¿½s Version) (From...   Taylor Swift
# 33                                           Anti-Hero   Taylor Swift
# 37                                         Blank Space   Taylor Swift
# 38                                               Style   Taylor Swift
# 59                                            cardigan   Taylor Swift
# 66                                               Karma   Taylor Swift
# 69                        Enchanted (Taylor's Version)   Taylor Swift
# 83                 Back To December (Taylor's Version)   Taylor Swift
# 93                                    Donï¿½ï¿½ï¿½t Bl   Taylor Swift
# 100                                              Lover   Taylor Swift
# 113                            Mine (Taylor's Version)   Taylor Swift
# ...

# %%
df_tay.track_name.nunique()
# Out:
# 34

# %%
fig=px.scatter(df_tay, y='track_name', x='released_year', color='released_year')
fig.update_layout(
    xaxis_title='Año',
    yaxis_title='Canción',
    title_text= format_title('Taylor','Proyecto'),
    template='plotly_white')
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#int('streams')
df_tay.streams.max()
# Out:
# 1355959075

# %%
df_taypop=df[(df['streams']==1355959075)]
df_taypop
# Out:
#      track_name artist(s)_name  artist_count  released_year  released_month  \
# 37  Blank Space   Taylor Swift             1           2014               1
#
#     released_day  in_spotify_playlists  in_spotify_charts     streams  \
# 37             1                 11434                 53  1355959075
#
#     in_apple_playlists  in_apple_charts
# 37                 154              123

# %%
fig=px.bar(df_tay,x='track_name', y='streams')
fig.update_layout(
    yaxis_title='Reproducciones',
    xaxis_title='Canción',
    title_text= format_title('Taylor','Proyecto'),
    template='plotly_white')
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_yo=df[(df['artist(s)_name']=='Lasso')]
df_yo
# Out:
#         track_name artist(s)_name  artist_count  released_year  \
# 867  Ojos Marrones          Lasso             1           2022
#
#      released_month  released_day  in_spotify_playlists  in_spotify_charts  \
# 867               2             6                   795                 11
#
#        streams  in_apple_playlists  in_apple_charts
# 867  263280370                  26               18

# %%
df.released_year.max()
# Out:
# 2023

# %%
df_ppp=df[(df['artist(s)_name']=='Peso Pluma')]
df_ppp
# Out:
#          track_name artist(s)_name  artist_count  released_year  \
# 124  Por las Noches     Peso Pluma             1           2021
# 151             Bye     Peso Pluma             1           2023
#
#      released_month  released_day  in_spotify_playlists  in_spotify_charts  \
# 124               6            11                   457                 24
# 151               5            26                   324                 14
#
#        streams  in_apple_playlists  in_apple_charts
# 124  330346424                   8              116
# 151   95053634                  13              110

# %%
df_pg=df[(df['artist(s)_name']=='Piter G')]
df_pg
# Out:
# Empty DataFrame
# Columns: [track_name, artist(s)_name, artist_count, released_year, released_month, released_day, in_spotify_playlists, in_spotify_charts, streams, in_apple_playlists, in_apple_charts]
# Index: []

# %%
df_BB=df[(df['artist(s)_name']=='Bad Bunny')]
df_BB
# Out:
#                track_name artist(s)_name  artist_count  released_year  \
# 4          WHERE SHE GOES      Bad Bunny             1           2023
# 192     Titi Me Preguntï¿      Bad Bunny             1           2022
# 239                Efecto      Bad Bunny             1           2022
# 362              Neverita      Bad Bunny             1           2022
# 377           Moscow Mule      Bad Bunny             1           2022
# 422              Yonaguni      Bad Bunny             1           2021
# 676           A Tu Merced      Bad Bunny             1           2020
# 716               La Zona      Bad Bunny             1           2020
# 766  Despuï¿½ï¿½s de la P      Bad Bunny             1           2022
# 767             Un Ratito      Bad Bunny             1           2022
# 770      Yo No Soy Celoso      Bad Bunny             1           2022
# 773  Me Fui de Vacaciones      Bad Bunny             1           2022
# ...

# %%
fig=px.scatter(df_BB, y='track_name', x='released_year', color='released_year')
fig.update_layout(
    xaxis_title='Año',
    yaxis_title='Canción',
    title_text= format_title('Bad Bunny','Proyecto'),
    template='plotly_white')
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig=px.bar(df_BB,x='track_name', y='streams', color='released_year')
fig.update_layout(
    yaxis_title='Reproducciones',
    xaxis_title='Canción',
    title_text= format_title('Bad Bunny','Proyecto'),
    template='plotly_white')
fig
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
